# %%
from collections import namedtuple
from requests import get
from bs4 import BeautifulSoup as bs

ep_structure = namedtuple('EP', 'temporada episodio nome')
URL = 'https://pt.wikipedia.org/wiki/Lista_de_epis%C3%B3dios_de_Samurai_X'

request = get(URL)

page = bs(request.content, 'lxml')
tables = page.findAll('table', {'class': 'wikitable'})

# Divisão de tabelas por temporada
temp_1, temp_2, temp_3 = tables


def get_rows(table):
    return table.findAll('tr')[1:]


# Linhas por tabela de temporada
t1_rows, t2_rows, t3_rows = map(get_rows, [temp_1, temp_2, temp_3])


# t1_rows[0].find_all('td')[0].text
# t1_rows[0].find_all('td')[3].text


def get_data(temp: int, rows: list) -> namedtuple:
    for row in rows:
        columns = row.find_all('td')
        ep = columns[0].text
        nome = columns[3].text
        yield ep_structure(temp, int(ep), nome)


# Dados por linha de cada temporada
t1_data, t2_data, t3_data = map(lambda t: list(get_data(t[0], t[1])),
                                enumerate([t1_rows, t2_rows, t3_rows], 1))

# Lista de todos os episodios
lista_episodios = sum([t1_data, t2_data, t3_data], [])

# %%
lista_episodios
# Out:
# [EP(temporada=1, episodio=1, nome='Kenshin Battousai, o Espadachim Legendário'),
#  EP(temporada=1, episodio=2, nome='O Aluno Rebelde'),
#  EP(temporada=1, episodio=3, nome='O Homem Que Deixou o Passado'),
#  EP(temporada=1, episodio=4, nome='O Lutador Sanosuke'),
#  EP(temporada=1, episodio=5, nome='Kenshin contra Zanza'),
#  EP(temporada=1, episodio=6, nome='O Visitante Que Veio Das Trevas'),
#  EP(temporada=1, episodio=7, nome='A Grande Luta'),
#  EP(temporada=1, episodio=8, nome='A Mulher Misteriosa'),
#  EP(temporada=1, episodio=9, nome='Uma Gangue Poderosa'),
#  EP(temporada=1, episodio=10, nome='A Tentativa de um Resgate'),
#  EP(temporada=1, episodio=11, nome='Uma Colisão Entre a Luz e as Trevas'),
#  EP(temporada=1, episodio=12, nome='O Nascimento de Um Espadachim'),
#  EP(temporada=1, episodio=13, nome='O Lutador de Sumô'),
#  EP(temporada=1, episodio=14, nome='A Médica Nova na Cidade'),
#  EP(temporada=1, episodio=15, nome='Os Retalhadores Legendários'),
#  EP(temporada=1, episodio=16, nome='A Hora da Verdade'),
#  EP(temporada=1, episodio=17, nome='Marimo, o Canhão Humano'),
#  EP(temporada=1, episodio=18, nome='A Luta de Yahiko'),
#  EP(temporada=1, episodio=19, nome='A Fantasia do Reino Proibido'),
#  EP(temporada=1, episodio=20, nome='A Volta do Estilo Shinko'),
#  EP(temporada=1, episodio=21, nome='A Ambição de Raijuuta'),
#  EP(temporada=1, episodio=22, nome='A Viagem de Trem'),
#  EP(temporada=1, episodio=23, nome='Sanosuke Volta ao Passado'),
#  EP(temporada=1, episodio=24, nome='Kenshin Contra Sanosuke'),
#  EP(temporada=1, episodio=25, nome='O Navio Pirata'),
#  EP(temporada=1, episodio=26, nome='A Famosa Pirata Shura'),
#  EP(temporada=1, episodio=27, nome='O Fim dos Piratas'),
#  EP(temporada=2, episodio=28, nome='O Retorno do Lobo'),
#  EP(temporada=2, episodio=29, nome='O Inimigo Mais Poderoso'),
#  EP(temporada=2, episodio=30, nome='A Vingança do Vilão'),
#  EP(temporada=2, episodio=31, nome='A Despedida de Kenshin'),
#  EP(temporada=2, episodio=32, nome='A Vida Sem Kenshin'),
#  EP(temporada=2, episodio=33, nome='À Procura de Kenshin'),
#  EP(temporada=2, episodio=34, nome='Uma Garota Valente'),
#  EP(temporada=2, episodio=35, nome='A Cidade Roubada'),
#  EP(temporada=2, episodio=36, nome='O Encontro de Shishio e Kenshin'),
#  EP(temporada=2, episodio=37, nome='Sojiro Versus Kenshin'),
#  EP(temporada=2, episodio=38, nome='O Treinamento de Sanosuke'),
#  EP(temporada=2, episodio=39, nome='A Espada Mais Poderosa'),
#  EP(temporada=2, episodio=40, nome='A Luta Fatal'),
#  EP(temporada=2, episodio=41, nome='O Encontro Com o Mestre'),
#  EP(temporada=2, episodio=42, nome='A Traição de Aoshi'),
#  EP(temporada=2, episodio=43, nome='Entre a Vida e a Morte'),
#  EP(temporada=2, episodio=44, nome='A Gangue Mais Poderosa'),
#  EP(temporada=2, episodio=45, nome='A Fuga de Shishio'),
#  EP(temporada=2, episodio=46, nome='O Navio de Aço'),
#  EP(temporada=2, episodio=47, nome='O Encontro da Gangue'),
#  EP(temporada=2, episodio=48, nome='O Passado de Anji'),
#  EP(temporada=2, episodio=49, nome='Os Olhos do Coração'),
#  EP(temporada=2, episodio=50, nome='Hora de Honrar a Promessa'),
#  EP(temporada=2, episodio=51, nome='O Duelo Continua'),
#  EP(temporada=2, episodio=52, nome='O Ataque a Aoiya'),
#  EP(temporada=2, episodio=53, nome='O Gigante versus o Super-Homem'),
#  EP(temporada=2, episodio=54, nome='O Paraíso Contra a Terra'),
#  EP(temporada=2, episodio=55, nome='O Passado de Sojiro'),
#  EP(temporada=2, episodio=56, nome='A Última Batalha de Sojiro'),
#  EP(temporada=2, episodio=57, nome='A Batalha Final'),
#  EP(temporada=2, episodio=58, nome='A Batalha Continua'),
#  EP(temporada=2, episodio=59, nome='A Luta Continua'),
#  EP(temporada=2, episodio=60, nome='Uma Luta Sem Vencedor'),
#  EP(temporada=2, episodio=61, nome='O Destino do Grupo Juppongatana'),
#  EP(temporada=2, episodio=62, nome='A Volta ao Lar'),
#  EP(temporada=3, episodio=63, nome='A Garota do Espadachim'),
#  EP(temporada=3, episodio=64, nome='Príncipe Por um Dia'),
#  EP(temporada=3, episodio=65, nome='O Cachorro Famoso'),
#  EP(temporada=3, episodio=66, nome='O Anel de Noivado'),
#  EP(temporada=3, episodio=67, nome='A Espada Lendária'),
#  EP(temporada=3, episodio=68, nome='A Profecia se Cumprirá'),
#  EP(temporada=3, episodio=69, nome='O Momento da Verdade'),
#  EP(temporada=3, episodio=70, nome='Kenshin Nas Trevas'),
#  EP(temporada=3, episodio=71, nome='A Traição'),
#  EP(temporada=3, episodio=72, nome='O Passado Triste de Shogo e Sayo'),
#  EP(temporada=3, episodio=73, nome='O Plano Para Matar'),
#  EP(temporada=3, episodio=74, nome='A Tristeza de Sanosuke'),
#  EP(temporada=3, episodio=75, nome='A Última Guerra Santa'),
#  EP(temporada=3, episodio=76, nome='Uma Nova Chance'),
#  EP(temporada=3, episodio=77, nome='Falsa Identidade?'),
#  EP(temporada=3, episodio=78, nome='O Artista'),
#  EP(temporada=3, episodio=79, nome='Aprendendo a Lutar'),
#  EP(temporada=3, episodio=80, nome='O Treinamento'),
#  EP(temporada=3, episodio=81, nome='Acontecimento em Shiragaya'),
#  EP(temporada=3, episodio=82, nome='Mais Precioso Que o Dinheiro'),
#  EP(temporada=3, episodio=83, nome='O Elixir Milagroso'),
#  EP(temporada=3, episodio=84, nome='Bálsamo Divino'),
#  EP(temporada=3, episodio=85, nome='A Armadilha Está Pronta'),
#  EP(temporada=3, episodio=86, nome='Dia Vermelho'),
#  EP(temporada=3, episodio=87, nome='O Fim dos Cavaleiros Negros'),
#  EP(temporada=3, episodio=88, nome='Promessa Eterna'),
#  EP(temporada=3, episodio=89, nome='Entrega Para Meu Anjo'),
#  EP(temporada=3, episodio=90, nome='O Mistério do Pentagrama'),
#  EP(temporada=3, episodio=91, nome='Próximo Alvo'),
#  EP(temporada=3, episodio=92, nome='Lei Marcial'),
#  EP(temporada=3, episodio=93, nome='O Inimigo Aguarda'),
#  EP(temporada=3, episodio=94, nome='O Desenlace Final'),
#  EP(temporada=3, episodio=95, nome='O Fim do Verão (Inédito no Brasil)')]
